# %% [markdown]
# # Procesamiento de Datos de Imágenes con la Clase `DataImages`
#
# ## Introducción
# Este notebook presenta el proceso de análisis de imágenes utilizando la clase `DataImages`, que se encarga de extraer, clasificar y calcular promedios de píxeles en imágenes relacionadas con el tráfico.
#
# ## 1. Importación de Bibliotecas
# Primero, asegúrate de importar las bibliotecas necesarias. Esto puede incluir bibliotecas como `os`, `numpy`, `matplotlib` y cualquier otra que uses en tu clase.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
